# %% [markdown]
# <a href="https://colab.research.google.com/github/wzh1998/CVPR-Learning/blob/main/Q5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

imgL = cv2.imread('1.JPG',0)
imgR = cv2.imread('2.JPG',0)

cv2.StereoBM_create(numDisparities=16, blockSize=15)
disparity = stereo.compute(imgL,imgR)
plt.imshow(disparity,'gray')
plt.show()
